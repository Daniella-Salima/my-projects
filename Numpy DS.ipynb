# %% [markdown]
# ## Numpy Exercise - Daniella Salima

# %%
import numpy as np

# %% [markdown]
# ## Execution

# %%
data = np.array([1,2,3,4,5])
print(data)
print(len(data))
print(type(data))
print(data.shape)
# Out:
# [1 2 3 4 5]
# 5
# <class 'numpy.ndarray'>
# (5,)

# %% [markdown]
# ## Exercises lecture slide

# %% [markdown]
# ### Import 2D  array

# %%
arrD = np.array([[25, 50, 75, 100], [20, 40, 60, 80]])

# %%
print(arrD)
# Out:
# [[ 25  50  75 100]
#  [ 20  40  60  80]]

# %% [markdown]
# ### Array Indexing

# %%
print(arrD[0])
# Out:
# [ 25  50  75 100]

# %% [markdown]
# ### Array slicing

# %%
print(arrD[0:2])
# Out:
# [[ 25  50  75 100]
#  [ 20  40  60  80]]

# %% [markdown]
# ### Array Sorting

# %%
print(np.sort(arrD))
# Out:
# [[ 25  50  75 100]
#  [ 20  40  60  80]]

# %%
arrA = np.array(['samsung', 'apple', 'infinix', 'techno', 'xiaomi'])

# %%
print(np.sort(arrA))
# Out:
# ['apple' 'infinix' 'samsung' 'techno' 'xiaomi']
